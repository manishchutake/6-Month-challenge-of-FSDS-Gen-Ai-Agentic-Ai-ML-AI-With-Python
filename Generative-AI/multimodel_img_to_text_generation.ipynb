# %%
pip install  -q  -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['GEMINI_API_KEY'] =''

# %%
import google.generativeai as genai
genai.configure(api_key = os.environ['GEMINI_API_KEY'])

# %%
import google.generativeai as genai

# %%
model = genai.GenerativeModel('models/gemini-2.5-flash-preview-09-2025')

# %%
from PIL import Image

img = Image.open(
    "/Users/manishuxuid/Desktop/Antigravity_IDE/young-bearded-man-with-striped-shirt.jpg"
)

# Resize (keep aspect ratio)
img_small = img.resize((400, 400))  # adjust size as needed
img_small

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('.', '*')
    return Markdown(textwrap.indent(text, '>', predicate=lambda _: True))

# %%
response = model.generate_content(img)
to_markdown(response.text)
# Out:
# >This is a medium close-up studio portrait of a smiling young adult male, set against a textured, light background*
# >
# >**Subject and Expression:**
# >The subject is a man with dark brown hair and a full, dark beard* He is looking directly at the camera with a cheerful, open-mouthed smile that displays both upper and lower teeth* His expression is warm and genuine, with visible crinkling (crow's feet) near the corners of his eyes* His hair is casually styled and slightly tousled on top*
# >
# >**Attire:**
# >He is wearing a casual, long-sleeved plaid button-down shirt left open over a plain white crewneck t-shirt* The plaid pattern features a prominent palette of colors: the main ground color is a vibrant coral or dusty rose pink, intersected by thick lines of dark navy blue, olive green, and thin accents of cream or off-white* The visible buttons on the shirt are a light brown or tan color*
# >
# >**Setting and Aesthetics:**
# >The man is centered in the frame* The background is uniformly light (white or very light gray) and features a rough, stippled texture, suggesting a stucco or plaster wall* The lighting is bright and even, casting minimal shadows, giving the image a clean, contemporary studio feel*
