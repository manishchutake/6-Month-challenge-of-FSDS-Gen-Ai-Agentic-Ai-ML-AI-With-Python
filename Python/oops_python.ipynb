# %% [markdown]
# #### 1- CLASS
# #### 2- METHOD
# #### 3- OBJECT
# #### 4- ENCAPSULATION
# #### 5- INHERITENCE
# #### 6- POLYMORPHISM
# #### 7- ABSTRACTION
#
# #----------------------------
#
# #### 8- ITERATOR
# #### 9- GENERATOR
# #### 10- MULTITHRADING

# %%
a = 5
print(type(a)) #inbuild class
# Out:
# <class 'int'>

# %%
l = [1,2,3]
print(type(l))
# Out:
# <class 'list'>

# %%
class computer():        
    def config():     
        print('i5', '8gb') 

com1 = computer()

# %%
class computer():        
    def config():     
        print('i5', '8gb') 
        
a = '8'
print(type(a))

com1 = computer() 
print(type(com1))
# Out:
# <class 'str'>
# <class '__main__.computer'>

# %%
print(id(a))
print(id(com1))
# Out:
# 140707038762640
# 1824858847568

# %%
class computer():        
    def config():     
        print('i5', '8gb') 
       
com1 = computer() 

computer.config()
# Out:
# i5 8gb

# %%
class computer():        
    def config():     
        print('i5', '8gb') 
        
com1 = computer() 
com1.config()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3         print('i5', '8gb')
#       4 com1 = computer()
# ----> 5 com1.config()
#
# TypeError: computer.config() takes 0 positional arguments but 1 was given

# %%
class computer():        
    def config(self):     
        print('i5', '8gb') 
        
com1 = computer() 

com1.config()
# Out:
# i5 8gb

# %%
class computer():        
    def config(self):     
        print('i5', '8gb') 
        
com1 = computer() 
com2 = computer()
com3 = computer()

com1.config()
com2.config()
com3.config()
# Out:
# i5 8gb
# i5 8gb
# i5 8gb

# %%
print(id(com1))
print(id(com2))
print(id(com3))
# Out:
# 1824864340112
# 1824860596336
# 1824864252320

# %%
__name__
# Out:
# '__main__'

# %% [markdown]
# # __ init__ method in python

# %%
class computer():        
    def config(self):     
        print('i5', '8gb') 
        
com1 = computer()

# %%
class computer():        
    def __init__(self):     
        print('i5', '8gb') 
        
com1 = computer()
# Out:
# i5 8gb

# %%
class computer():        
    def __init__(self):     
        print('i5', '8gb') 
        
com1 = computer() 
com1.__init__()
# Out:
# i5 8gb
# i5 8gb

# %%
class computer():        
    
    def __init__(self):
        print('in init')
    
    def config(self):     
        print('i5', '8gb')

# %%
class computer():        
    
    def __init__(self):
        print('in init')
    
    def config(self):     
        print('i5', '8gb')

com1 = computer()
com2 = computer()
com3 = computer()
# Out:
# in init
# in init
# in init

# %%
class computer():        
    
    def __init__(self):
        print('in init')
    
    def config(self):     
        print('i5', '8gb')

com1 = computer()
com2 = computer()
com3 = computer()


com1.config()
com2.config()
com3.config()
# Out:
# in init
# in init
# in init
# i5 8gb
# i5 8gb
# i5 8gb

# %%
class computer():    
    
    def __init__(self):
        print('in init')
        
    def config(self):     
        print('i5', '8gb')
        
std1 = computer('i5', 8)
std2 = computer('i7', 16)

std1.config() 
std2.config()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 9
#       6     def config(self):
#       7         print('i5', '8gb')
# ----> 9 std1 = computer('i5', 8)
#      10 std2 = computer('i7', 16)
#      12 std1.config()
#
# TypeError: computer.__init__() takes 1 positional argument but 3 were given

# %%
class computer():    
    
    def __init__(self, cpu, ram):
        print('in init')
        
    def config(self):     
        print('i5', 8)
        print('i7', 16)
        
std1 = computer('i5', 8)
std2 = computer('i7', 16)

std1.config() 
#std2.config()
# Out:
# in init
# in init
# i5 8
# i7 16

# %%
class computer():    
    
    def __init__(self, cpu, ram, price):
        print('in init')
        
    def config(self):     
        print('i5', 8)
        print('i7', 16)
        print('i7', 30000)
        
std1 = computer('i5', 8, 30000)
std2 = computer('i7', 16, 50000)

std1.config() 
#std2.config()
# Out:
# in init
# in init
# i5 8
# i7 16
# i7 30000

# %%
class computer():        
    
    def __init__(self,cpu,ram, price): # cpu & ram as argument
        self.cpu = cpu
        self.ram = ram 
        self.price= price
        #print('init')
    
    def config(self):     
        print('config is', self.cpu, self.ram, self.price)

com1 = computer('i5', 8, 2000)
com2 = computer('i7', 16, 3000)

com1.config() 
com2.config()
# Out:
# config is i5 8 2000
# config is i7 16 3000
