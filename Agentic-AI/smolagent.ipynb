# %%
pip install smolagents
# Out:
# Collecting smolagents
#   Downloading smolagents-1.23.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.31.2 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from smolagents) (0.36.0)
# Requirement already satisfied: requests>=2.32.3 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from smolagents) (2.32.5)
# Requirement already satisfied: rich>=13.9.4 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from smolagents) (14.2.0)
# Requirement already satisfied: jinja2>=3.1.4 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from smolagents) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from smolagents) (11.3.0)
# Collecting python-dotenv (from smolagents)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (2025.10.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from jinja2>=3.1.4->smolagents) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from requests>=2.32.3->smolagents) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from requests>=2.32.3->smolagents) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from requests>=2.32.3->smolagents) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from requests>=2.32.3->smolagents) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from rich>=13.9.4->smolagents) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from rich>=13.9.4->smolagents) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/ai-env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)
# Downloading smolagents-1.23.0-py3-none-any.whl (148 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv, smolagents
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [smolagents]2 [smolagents]
# Successfully installed python-dotenv-1.2.1 smolagents-1.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 

os.environ["HF_TOKEN"] = ""

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, TransformersModel

# %%
pip install duckduckgo-DuckDuckGo Search
# Out:
# ERROR: Could not find a version that satisfies the requirement duckduckgo-DuckDuckGo (from versions: none)
# ERROR: No matching distribution found for duckduckgo-DuckDuckGo
# Note: you may need to restart the kernel to use updated packages.

# %%
model  = TransformersModel() 
agent  = CodeAgent(tools = [DuckDuckGoSearchTool()], model = model)
