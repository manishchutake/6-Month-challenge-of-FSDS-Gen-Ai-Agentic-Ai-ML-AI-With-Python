# %%
# !pip install crewai
# !pip install duckduckgo-search
# !pip install huggingface_hub
# !pip install langchain_google_genai
# Out:
# Requirement already satisfied: crewai in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: aiosqlite~=0.21.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.21.0)
# Requirement already satisfied: appdirs~=1.4.4 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.4.4)
# Requirement already satisfied: chromadb~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.1.1)
# Requirement already satisfied: click~=8.1.7 in /usr/local/lib/python3.12/dist-packages (from crewai) (8.1.8)
# Requirement already satisfied: instructor>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.12.0)
# Requirement already satisfied: json-repair~=0.25.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.25.3)
# Requirement already satisfied: json5~=0.10.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.10.0)
# Requirement already satisfied: jsonref~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.1.0)
# Requirement already satisfied: mcp~=1.16.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.16.0)
# Requirement already satisfied: openai~=1.83.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.83.0)
# Requirement already satisfied: openpyxl~=3.1.5 in /usr/local/lib/python3.12/dist-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api~=1.34.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http~=1.34.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk~=1.34.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.34.1)
# Requirement already satisfied: pdfplumber~=0.11.4 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.11.8)
# Requirement already satisfied: portalocker~=2.7.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.7.0)
# Requirement already satisfied: pydantic-settings~=2.10.1 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.10.1)
# Requirement already satisfied: pydantic~=2.11.9 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.11.10)
# Requirement already satisfied: pyjwt~=2.9.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.9.0)
# Requirement already satisfied: python-dotenv~=1.1.1 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.1.1)
# Requirement already satisfied: regex~=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from crewai) (2024.9.11)
# Requirement already satisfied: tokenizers~=0.20.3 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.20.3)
# Requirement already satisfied: tomli-w~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.1.0)
# Requirement already satisfied: tomli~=2.0.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.0.2)
# Requirement already satisfied: uv~=0.9.13 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.9.20)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.12/dist-packages (from aiosqlite~=0.21.0->crewai) (4.15.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (2.0.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.23.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.34.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (4.25.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (3.13.2)
# Requirement already satisfied: diskcache>=5.6.3 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (5.6.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (0.17.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (3.1.6)
# Requirement already satisfied: jiter<0.11,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (0.10.0)
# Requirement already satisfied: pre-commit>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (4.5.1)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (2.33.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (2.32.5)
# Requirement already satisfied: anyio>=4.5 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.16.0->crewai) (4.12.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.16.0->crewai) (0.4.3)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.16.0->crewai) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.16.0->crewai) (3.0.4)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.16.0->crewai) (0.50.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai~=1.83.0->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai~=1.83.0->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl~=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api~=1.34.0->crewai) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.34.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-proto==1.34.1->opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk~=1.34.0->crewai) (0.55b1)
# Requirement already satisfied: pdfminer.six==20251107 in /usr/local/lib/python3.12/dist-packages (from pdfplumber~=0.11.4->crewai) (20251107)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.12/dist-packages (from pdfplumber~=0.11.4->crewai) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from pdfplumber~=0.11.4->crewai) (5.2.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251107->pdfplumber~=0.11.4->crewai) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251107->pdfplumber~=0.11.4->crewai) (43.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.11.9->crewai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.11.9->crewai) (0.4.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers~=0.20.3->crewai) (0.36.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.22.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=4.5->mcp~=1.16.0->crewai) (3.11)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (25.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb~=1.1.0->crewai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb~=1.1.0->crewai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb~=1.1.0->crewai) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers~=0.20.3->crewai) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers~=0.20.3->crewai) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers~=0.20.3->crewai) (1.2.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.34.0->crewai) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.45.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.10)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (25.9.23)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.14.0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.2.1)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (1.10.0)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (20.35.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (2.19.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (15.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber~=0.11.4->crewai) (2.0.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (4.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb~=1.1.0->crewai) (0.1.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor>=1.3.3->crewai) (0.4.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor>=1.3.3->crewai) (4.5.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber~=0.11.4->crewai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.6.1)
# Requirement already satisfied: duckduckgo-search in /usr/local/lib/python3.12/dist-packages (8.1.1)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from duckduckgo-search) (8.1.8)
# Requirement already satisfied: primp>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from duckduckgo-search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from duckduckgo-search) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2025.11.12)
# Requirement already satisfied: langchain_google_genai in /usr/local/lib/python3.12/dist-packages (4.1.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (1.56.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (1.2.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (2.11.10)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.12.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.45.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.45.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (0.4.59)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (0.12.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (3.11)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain_google_genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.6.1)

# %%
# !pip install 'crewai[tools]'
# Out:
# Requirement already satisfied: crewai[tools] in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: aiosqlite~=0.21.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (0.21.0)
# Requirement already satisfied: appdirs~=1.4.4 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (1.4.4)
# Requirement already satisfied: chromadb~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (1.1.1)
# Requirement already satisfied: click~=8.1.7 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (8.1.8)
# Requirement already satisfied: instructor>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (1.12.0)
# Requirement already satisfied: json-repair~=0.25.2 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (0.25.3)
# Requirement already satisfied: json5~=0.10.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (0.10.0)
# Requirement already satisfied: jsonref~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (1.1.0)
# Requirement already satisfied: mcp~=1.16.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (1.16.0)
# Requirement already satisfied: openai~=1.83.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (1.83.0)
# Requirement already satisfied: openpyxl~=3.1.5 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (3.1.5)
# Requirement already satisfied: opentelemetry-api~=1.34.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http~=1.34.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk~=1.34.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (1.34.1)
# Requirement already satisfied: pdfplumber~=0.11.4 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (0.11.8)
# Requirement already satisfied: portalocker~=2.7.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (2.7.0)
# Requirement already satisfied: pydantic-settings~=2.10.1 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (2.10.1)
# Requirement already satisfied: pydantic~=2.11.9 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (2.11.10)
# Requirement already satisfied: pyjwt~=2.9.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (2.9.0)
# Requirement already satisfied: python-dotenv~=1.1.1 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (1.1.1)
# Requirement already satisfied: regex~=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (2024.9.11)
# Requirement already satisfied: tokenizers~=0.20.3 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (0.20.3)
# Requirement already satisfied: tomli-w~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (1.1.0)
# Requirement already satisfied: tomli~=2.0.2 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (2.0.2)
# Requirement already satisfied: uv~=0.9.13 in /usr/local/lib/python3.12/dist-packages (from crewai[tools]) (0.9.20)
# Collecting crewai-tools==1.7.2 (from crewai[tools])
#   Downloading crewai_tools-1.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4~=4.13.4 in /usr/local/lib/python3.12/dist-packages (from crewai-tools==1.7.2->crewai[tools]) (4.13.5)
# Collecting docker~=7.1.0 (from crewai-tools==1.7.2->crewai[tools])
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting lancedb~=0.5.4 (from crewai-tools==1.7.2->crewai[tools])
#   Downloading lancedb-0.5.7-py3-none-any.whl.metadata (17 kB)
# Collecting pymupdf~=1.26.6 (from crewai-tools==1.7.2->crewai[tools])
#   Downloading pymupdf-1.26.7-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Collecting python-docx~=1.2.0 (from crewai-tools==1.7.2->crewai[tools])
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting pytube~=15.0.0 (from crewai-tools==1.7.2->crewai[tools])
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting requests~=2.32.5 (from crewai-tools==1.7.2->crewai[tools])
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tiktoken~=0.8.0 (from crewai-tools==1.7.2->crewai[tools])
#   Downloading tiktoken-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting youtube-transcript-api~=1.2.2 (from crewai-tools==1.7.2->crewai[tools])
#   Downloading youtube_transcript_api-1.2.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.12/dist-packages (from aiosqlite~=0.21.0->crewai[tools]) (4.15.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai[tools]) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (2.0.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (1.23.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (1.34.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai[tools]) (4.25.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai[tools]) (3.13.2)
# Requirement already satisfied: diskcache>=5.6.3 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai[tools]) (5.6.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai[tools]) (0.17.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai[tools]) (3.1.6)
# Requirement already satisfied: jiter<0.11,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai[tools]) (0.10.0)
# Requirement already satisfied: pre-commit>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai[tools]) (4.5.1)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai[tools]) (2.33.2)
# Requirement already satisfied: anyio>=4.5 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.16.0->crewai[tools]) (4.12.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.16.0->crewai[tools]) (0.4.3)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.16.0->crewai[tools]) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.16.0->crewai[tools]) (3.0.4)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.16.0->crewai[tools]) (0.50.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai~=1.83.0->crewai[tools]) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai~=1.83.0->crewai[tools]) (1.3.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl~=3.1.5->crewai[tools]) (2.0.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api~=1.34.0->crewai[tools]) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai[tools]) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai[tools]) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai[tools]) (1.34.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-proto==1.34.1->opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai[tools]) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk~=1.34.0->crewai[tools]) (0.55b1)
# Requirement already satisfied: pdfminer.six==20251107 in /usr/local/lib/python3.12/dist-packages (from pdfplumber~=0.11.4->crewai[tools]) (20251107)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.12/dist-packages (from pdfplumber~=0.11.4->crewai[tools]) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from pdfplumber~=0.11.4->crewai[tools]) (5.2.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251107->pdfplumber~=0.11.4->crewai[tools]) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251107->pdfplumber~=0.11.4->crewai[tools]) (43.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.11.9->crewai[tools]) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.11.9->crewai[tools]) (0.4.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers~=0.20.3->crewai[tools]) (0.36.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai[tools]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai[tools]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai[tools]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai[tools]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai[tools]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai[tools]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai[tools]) (1.22.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=4.5->mcp~=1.16.0->crewai[tools]) (3.11)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4~=4.13.4->crewai-tools==1.7.2->crewai[tools]) (2.8)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb~=1.1.0->crewai[tools]) (25.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb~=1.1.0->crewai[tools]) (1.2.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker~=7.1.0->crewai-tools==1.7.2->crewai[tools]) (2.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb~=1.1.0->crewai[tools]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb~=1.1.0->crewai[tools]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb~=1.1.0->crewai[tools]) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers~=0.20.3->crewai[tools]) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers~=0.20.3->crewai[tools]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers~=0.20.3->crewai[tools]) (1.2.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.34.0->crewai[tools]) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai[tools]) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai[tools]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai[tools]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai[tools]) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai[tools]) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai[tools]) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai[tools]) (2.45.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai[tools]) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai[tools]) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai[tools]) (0.10)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.12/dist-packages (from lancedb~=0.5.4->crewai-tools==1.7.2->crewai[tools]) (2.1.0)
# Collecting pylance==0.9.18 (from lancedb~=0.5.4->crewai-tools==1.7.2->crewai[tools])
#   Downloading pylance-0.9.18-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Collecting ratelimiter~=1.0 (from lancedb~=0.5.4->crewai-tools==1.7.2->crewai[tools])
#   Downloading ratelimiter-1.2.0.post0-py3-none-any.whl.metadata (4.0 kB)
# Collecting retry>=0.9.2 (from lancedb~=0.5.4->crewai-tools==1.7.2->crewai[tools])
#   Downloading retry-0.9.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting semver>=3.0 (from lancedb~=0.5.4->crewai-tools==1.7.2->crewai[tools])
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from lancedb~=0.5.4->crewai-tools==1.7.2->crewai[tools]) (6.2.4)
# Requirement already satisfied: pyarrow>=12 in /usr/local/lib/python3.12/dist-packages (from pylance==0.9.18->lancedb~=0.5.4->crewai-tools==1.7.2->crewai[tools]) (18.1.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai[tools]) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai[tools]) (25.9.23)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai[tools]) (1.14.0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai[tools]) (2.2.1)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai[tools]) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai[tools]) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai[tools]) (1.10.0)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai[tools]) (20.35.4)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx~=1.2.0->crewai-tools==1.7.2->crewai[tools]) (6.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai[tools]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai[tools]) (2.19.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai[tools]) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai[tools]) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai[tools]) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai[tools]) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai[tools]) (15.0.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api~=1.2.2->crewai-tools==1.7.2->crewai[tools]) (0.7.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber~=0.11.4->crewai[tools]) (2.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai[tools]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai[tools]) (4.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb~=1.1.0->crewai[tools]) (0.1.2)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from retry>=0.9.2->lancedb~=0.5.4->crewai-tools==1.7.2->crewai[tools]) (4.4.2)
# Collecting py<2.0.0,>=1.4.26 (from retry>=0.9.2->lancedb~=0.5.4->crewai-tools==1.7.2->crewai[tools])
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor>=1.3.3->crewai[tools]) (0.4.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor>=1.3.3->crewai[tools]) (4.5.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai[tools]) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb~=1.1.0->crewai[tools]) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai[tools]) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber~=0.11.4->crewai[tools]) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai[tools]) (0.6.1)
# Downloading crewai_tools-1.7.2-py3-none-any.whl (766 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.8/766.8 kB 23.6 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 16.4 MB/s eta 0:00:00
# Downloading lancedb-0.5.7-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 12.1 MB/s eta 0:00:00
# Downloading pylance-0.9.18-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.6/21.6 MB 105.3 MB/s eta 0:00:00
# Downloading pymupdf-1.26.7-cp310-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 109.0 MB/s eta 0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 24.9 MB/s eta 0:00:00
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.8 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 7.0 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.7 MB/s eta 0:00:00
# Downloading youtube_transcript_api-1.2.3-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.1/485.1 kB 37.8 MB/s eta 0:00:00
# Downloading ratelimiter-1.2.0.post0-py3-none-any.whl (6.6 kB)
# Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 11.1 MB/s eta 0:00:00
# Installing collected packages: ratelimiter, semver, requests, pytube, python-docx, pymupdf, pylance, py, youtube-transcript-api, tiktoken, retry, docker, lancedb, crewai-tools
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.12.0
#     Uninstalling tiktoken-0.12.0:
#       Successfully uninstalled tiktoken-0.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.43.0, but you have google-auth 2.45.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# google-adk 1.21.0 requires opentelemetry-api<=1.37.0,>=1.37.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# google-adk 1.21.0 requires opentelemetry-exporter-otlp-proto-http>=1.36.0, but you have opentelemetry-exporter-otlp-proto-http 1.34.1 which is incompatible.
# google-adk 1.21.0 requires opentelemetry-sdk<=1.37.0,>=1.37.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-api>=1.35.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# transformers 4.57.3 requires tokenizers<=0.23.0,>=0.22.0, but you have tokenizers 0.20.3 which is incompatible.
# Successfully installed crewai-tools-1.7.2 docker-7.1.0 lancedb-0.5.7 py-1.11.0 pylance-0.9.18 pymupdf-1.26.7 python-docx-1.2.0 pytube-15.0.0 ratelimiter-1.2.0.post0 requests-2.32.5 retry-0.9.2 semver-3.0.4 tiktoken-0.8.0 youtube-transcript-api-1.2.3

# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (1.2.5)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.45)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.59)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Downloading langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.11.10)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.12.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.33.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 44.8 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.1 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 5.3 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain-text-splitters, langchain-classic, langchain_community
# Successfully installed dataclasses-json-0.6.7 langchain-classic-1.0.1 langchain-text-splitters-1.1.0 langchain_community-0.4.1 marshmallow-3.26.2 mypy-extensions-1.1.0 typing-inspect-0.9.0

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from crewai import Agent, Task, Crew, Process
from langchain_community.tools import DuckDuckGoSearchRun

# %% [markdown]
# set up LLM

# %%
llm = ChatGoogleGenerativeAI(model  = "gemini-2.5-flash-8b-exp-0827",
                             verbose = True,
                             temprature = 0.2,
                             google_api_key = "")
# Out:
# WARNING:langchain_google_genai.chat_models:Unexpected argument 'temprature' provided to ChatGoogleGenerativeAI. Did you mean: 'temperature'?
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3553: UserWarning: WARNING! temprature is not default parameter.
#                 temprature was transferred to model_kwargs.
#                 Please confirm that temprature is what you intended.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
llm
# Out:
# ChatGoogleGenerativeAI(profile={}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash-8b-exp-0827', client=<google.genai.client.Client object at 0x7df62a894ce0>, default_metadata=(), model_kwargs={'temprature': 0.2})

# %% [markdown]
# set up tools

# %%
# !pip install duckduckgo_search
# Out:
# Requirement already satisfied: duckduckgo_search in /usr/local/lib/python3.12/dist-packages (8.1.1)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from duckduckgo_search) (8.1.8)
# Requirement already satisfied: primp>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from duckduckgo_search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from duckduckgo_search) (6.0.2)

# %%
# !pip install -U ddgs
# Out:
# Collecting ddgs
#   Downloading ddgs-9.10.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from ddgs) (8.1.8)
# Requirement already satisfied: primp>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from ddgs) (0.15.0)
# Requirement already satisfied: lxml>=4.9.4 in /usr/local/lib/python3.12/dist-packages (from ddgs) (6.0.2)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Collecting fake-useragent>=2.2.0 (from ddgs)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.3.0)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.1.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.15.0)
# Downloading ddgs-9.10.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 3.0 MB/s eta 0:00:00
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 10.4 MB/s eta 0:00:00
# Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Installing collected packages: socksio, fake-useragent, ddgs
# Successfully installed ddgs-9.10.0 fake-useragent-2.2.0 socksio-1.0.0

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

# %% [markdown]
# setup agents

# %%
import os
from crewai import Agent, Task, Crew, LLM


# Recommended: set this in system environment
os.environ["GOOGLE_API_KEY"] = os.getenv(
    "GOOGLE_API_KEY", ""
)


gemini_llm = LLM(
    model="gemini-2.5-flash",
    temperature=0.3
)



research_agent = Agent(
    role="AI Researcher",
    goal="Research latest trends in Generative AI and Agentic AI",
    backstory=(
        "You are a senior AI researcher with deep expertise in "
        "LLMs, Agentic AI, multi-agent systems, and enterprise GenAI adoption."
    ),
    llm=gemini_llm,
    verbose=True
)

writer_agent = Agent(
    role="Technical Writer",
    goal="Convert research into a clear technical explanation",
    backstory=(
        "You are an expert technical writer who explains complex "
        "AI concepts clearly for professionals and students."
    ),
    llm=gemini_llm,
    verbose=True
)

reviewer_agent = Agent(
    role="AI Reviewer",
    goal="Review content for accuracy, clarity, and workshop readiness",
    backstory=(
        "You ensure the AI content is technically accurate, well-structured, "
        "and suitable for hands-on workshops."
    ),
    llm=gemini_llm,
    verbose=True
)



research_task = Task(
    description=(
        "Research the top Generative AI and Agentic AI trends in 2025. "
        "Focus on:\n"
        "- Large Language Models (LLMs)\n"
        "- Agentic AI & multi-agent systems\n"
        "- Enterprise adoption\n"
        "- Tools and frameworks"
    ),
    expected_output="A concise bullet-point research summary",
    agent=research_agent
)

writing_task = Task(
    description=(
        "Write a clean, structured technical explanation based on "
        "the research output. The content should:\n"
        "- Be suitable for a workshop\n"
        "- Include headings and bullet points\n"
        "- Be easy to understand for working professionals"
    ),
    expected_output="A well-structured technical article",
    agent=writer_agent
)

review_task = Task(
    description=(
        "Review the technical explanation for:\n"
        "- Accuracy\n"
        "- Clarity\n"
        "- Logical flow\n"
        "- Suitability for workshops\n\n"
        "Provide the final polished version."
    ),
    expected_output="Final reviewed and polished workshop-ready content",
    agent=reviewer_agent
)



crew = Crew(
    agents=[research_agent, writer_agent, reviewer_agent],
    tasks=[research_task, writing_task, review_task],
    verbose=True
)


if __name__ == "__main__":
    result = crew.kickoff()

    print("\n" + "=" * 80)
    print("FINAL OUTPUT")
    print("=" * 80)
    print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 113d7cf6-163d-49f0-9723-e7369b327357                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: AI Researcher                                                                                           │
# │                                                                                                                 │
# │  Task: Research the top Generative AI and Agentic AI trends in 2025. Focus on:                                  │
# │  - Large Language Models (LLMs)                                                                                 │
# │  - Agentic AI & multi-agent systems                                                                             │
# │  - Enterprise adoption                                                                                          │
# │  - Tools and frameworks                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: AI Researcher                                                                                           │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are the top Generative AI and Agentic AI trends anticipated for 2025:                                     │
# │                                                                                                                 │
# │  *   **Large Language Models (LLMs)**                                                                           │
# │      *   **Multimodality as the Default:** LLMs will natively process and generate across text, image, audio,   │
# │  video, and potentially other sensory data types, moving beyond text-centric capabilities to truly understand   │
# │  and interact with the world in a more holistic manner.                                                         │
# │      *   **Specialized and Efficient Models (SLMs/sLLMs):** The trend will shift towards smaller, highly        │
# │  specialized, and fine-tuned models (Small Language Models) optimized for specific domains, tasks, and edge     │
# │  deployments, offering superior performance, lower latency, and reduced inference costs compared to             │
# │  general-purpose large models.                                                                                  │
# │      *   **Enhanced Reasoning and Planning Capabilities:** Significant advancements in LLM architectures and    │
# │  training methodologies will lead to improved logical reasoning, complex problem-solving, multi-step planning,  │
# │  and self-correction, reducing "hallucinations" and increasing reliability for critical applications.           │
# │      *   **Deep Personalization and Contextual Awareness:** LLMs will become adept at understanding individual  │
# │  user preferences, historical interactions, and real-time context, enabling highly personalized experiences in  │
# │  customer service, content generation, and intelligent assistance.                                              │
# │      *   **Cost-Efficiency and Optimization:** Continued innovation in model compression (quantization,         │
# │  distillation), efficient inference techniques, and novel architectures will drastically reduce the             │
# │  operational costs of deploying and scaling LLMs, making them more accessible for broader enterprise adoption.  │
# │      *   **Robust Alignment and Safety Guardrails:** Greater emphasis on developing sophisticated alignment     │
# │  techniques, bias detection and mitigation strategies, and robust safety protocols to ensure LLMs are fair,     │
# │  transparent, and operate within ethical boundaries, particularly in sensitive applications.                    │
# │                                                                                                                 │
# │  *   **Agentic AI & Multi-Agent Systems**                                                                       │
# │      *   **Autonomous Agent Workflows in Production:** Agentic AI will move beyond experimental setups into     │
# │  production environments, enabling autonomous agents to execute complex, multi-step tasks, utilize diverse      │
# │  tools, and self-correct errors with minimal human oversight across various business functions.                 │
# │      *   **Sophisticated Human-Agent Collaboration:** The focus will shift from simple human-in-the-loop        │
# │  validation to deep collaborative frameworks where humans and AI agents work synergistically, with agents       │
# │  proactively seeking human input for ambiguity, complex decisions, or ethical considerations.                   │
# │      *   **Emergence of Agent Orchestration Platforms:** Dedicated platforms will mature to manage, monitor,    │
# │  and coordinate multiple specialized agents, defining roles, communication protocols, task dependencies, and    │
# │  resource allocation within complex multi-agent systems.                                                        │
# │      *   **Domain-Specific Intelligent Agents:** A proliferation of highly specialized agents will emerge,      │
# │  deeply embedded with domain knowledge and access to proprietary tools and data, tailored for specific          │
# │  industries like legal, finance, healthcare, and engineering.                                                   │
# │      *   **Adaptive and Self-Improving Agents:** Agents will increasingly incorporate continuous learning       │
# │  mechanisms, allowing them to adapt to new information, learn from feedback, and improve their performance and  │
# │  decision-making capabilities over time without explicit retraining.                                            │
# │      *   **Standardization of Agent Protocols:** Efforts will intensify to establish common communication       │
# │  protocols, API standards, and interoperability frameworks for agents, fostering a more cohesive and scalable   │
# │  multi-agent ecosystem.                                                                                         │
# │                                                                                                                 │
# │  *   **Enterprise Adoption**                                                                                    │
# │      *   **GenAI as a Core Business Process Automation Enabler:** Enterprises will integrate GenAI and agentic  │
# │  systems directly into core operational processes, automating tasks in areas like supply chain management,      │
# │  R&D, legal discovery, software development, and customer experience, driving significant efficiency gains.     │
# │      *   **Hybrid and On-Premise Deployments for Data Sovereignty:** Increased demand for deploying GenAI       │
# │  models and agentic systems within private cloud environments or on-premise to meet stringent data privacy,     │
# │  security, compliance, and intellectual property requirements.                                                  │
# │      *   **Data-Centric AI for Competitive Advantage:** Enterprises will heavily invest in curating, cleaning,  │
# │  and leveraging their proprietary data for fine-tuning LLMs and enhancing Retrieval Augmented Generation (RAG)  │
# │  systems, recognizing that unique data is key to differentiated GenAI capabilities and reducing                 │
# │  hallucinations.                                                                                                │
# │      *   **ROI-Driven Implementations and Value Realization:** The focus will shift from exploratory pilots to  │
# │  measurable business outcomes and clear return on investment (ROI) for GenAI initiatives, requiring robust      │
# │  metrics and strategic alignment with business goals.                                                           │
# │      *   **Workforce Transformation and Upskilling:** Significant investment in training and reskilling         │
# │  programs for employees to effectively interact with, manage, and leverage GenAI and agentic tools, fostering   │
# │  a human-AI augmented workforce.                                                                                │
# │      *   **Robust Governance, Risk, and Compliance (GRC) Frameworks:** Development and implementation of        │
# │  comprehensive internal policies, ethical guidelines, and technical controls to manage the risks associated     │
# │  with GenAI, including data leakage, bias, intellectual property, and regulatory compliance.                    │
# │      *   **Vertical-Specific GenAI Solutions:** A surge in industry-tailored GenAI applications and platforms,  │
# │  offering pre-trained models and specialized tools designed to address unique challenges and opportunities      │
# │  within specific sectors.                                                                                       │
# │                                                                                                                 │
# │  *   **Tools and Frameworks**                                                                                   │
# │      *   **Advanced Agent Orchestration and Management Platforms:** Evolution of frameworks like LangChain and  │
# │  AutoGen into comprehensive enterprise-grade platforms offering robust features for agent lifecycle             │
# │  management, monitoring, debugging, security, and scalable deployment of multi-agent systems.                   │
# │      *   **Next-Generation RAG Systems:** Tools for Retrieval Augmented Generation will become significantly    │
# │  more sophisticated, incorporating multi-modal retrieval, knowledge graph integration, semantic search, and     │
# │  adaptive retrieval strategies to provide more accurate, contextually rich, and up-to-date responses.           │
# │      *   **Model Evaluation, Observability, and Governance (MLEO) for GenAI:** Specialized tools will emerge    │
# │  to address the unique challenges of evaluating, monitoring, and governing GenAI models in production,          │
# │  focusing on hallucination detection, bias monitoring, prompt injection defense, and performance drift.         │
# │      *   **Low-Code/No-Code GenAI Development Environments:** Platforms will empower business users and         │
# │  citizen developers to build, customize, and deploy GenAI applications and agentic workflows with minimal       │
# │  coding, democratizing access to advanced AI capabilities.                                                      │
# │      *   **Open-Source Dominance and Innovation:** The open-source community will continue to drive rapid       │
# │  innovation in LLM architectures, agent frameworks, and specialized tooling, often providing more flexible,     │
# │  customizable, and cost-effective alternatives to proprietary solutions.                                        │
# │      *   **Enhanced Data Preparation and Annotation Tools for GenAI:** Specialized tools will streamline the    │
# │  process of curating, cleaning, augmenting, and annotating high-quality datasets specifically for LLM           │
# │  fine-tuning, RAG system development, and prompt engineering.                                                   │
# │      *   **AI Security and Red Teaming Tools:** A new generation of tools will focus on identifying and         │
# │  mitigating security vulnerabilities, adversarial attacks, and potential misuse of GenAI models, including      │
# │  prompt injection, data exfiltration, and model poisoning.                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1896f9b3-9be7-4066-9f1c-1b491d6ded8e                                                                     │
# │  Agent: AI Researcher                                                                                           │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technical Writer                                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # Generative AI & Agentic AI Trends 2025: A Technical Workshop Overview                                        │
# │                                                                                                                 │
# │  Welcome to this workshop on the anticipated trends shaping Generative AI and Agentic AI in 2025. We'll         │
# │  explore how these technologies are evolving, their impact on enterprise adoption, and the tools and            │
# │  frameworks driving their development. Our goal is to provide a clear, structured understanding for             │
# │  professionals looking to leverage these advancements.                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## 1. Large Language Models (LLMs): Evolution and Capabilities                                                 │
# │                                                                                                                 │
# │  Large Language Models are rapidly advancing beyond their text-centric origins, becoming more versatile,        │
# │  intelligent, and efficient.                                                                                    │
# │                                                                                                                 │
# │  *   **Multimodality as the Default**                                                                           │
# │      *   LLMs will natively process and generate content across various data types: text, images, audio,        │
# │  video, and potentially other sensory inputs.                                                                   │
# │      *   This shift enables a more holistic understanding of and interaction with the world, moving beyond      │
# │  simple text processing.                                                                                        │
# │                                                                                                                 │
# │  *   **Specialized and Efficient Models (SLMs/sLLMs)**                                                          │
# │      *   Expect a strong trend towards smaller, highly specialized, and fine-tuned models (Small Language       │
# │  Models).                                                                                                       │
# │      *   These models are optimized for specific domains, tasks, or edge deployments, offering superior         │
# │  performance, lower latency, and reduced inference costs compared to large, general-purpose models.             │
# │                                                                                                                 │
# │  *   **Enhanced Reasoning and Planning Capabilities**                                                           │
# │      *   Significant architectural and training advancements will lead to improved logical reasoning, complex   │
# │  problem-solving, multi-step planning, and self-correction.                                                     │
# │      *   This will reduce "hallucinations" and increase reliability, making LLMs suitable for critical          │
# │  applications.                                                                                                  │
# │                                                                                                                 │
# │  *   **Deep Personalization and Contextual Awareness**                                                          │
# │      *   LLMs will become highly adept at understanding individual user preferences, historical interactions,   │
# │  and real-time context.                                                                                         │
# │      *   This enables highly personalized experiences in areas like customer service, content generation, and   │
# │  intelligent assistance.                                                                                        │
# │                                                                                                                 │
# │  *   **Cost-Efficiency and Optimization**                                                                       │
# │      *   Continuous innovation in model compression (e.g., quantization, distillation), efficient inference     │
# │  techniques, and novel architectures will drastically reduce operational costs.                                 │
# │      *   This makes deploying and scaling LLMs more accessible for broader enterprise adoption.                 │
# │                                                                                                                 │
# │  *   **Robust Alignment and Safety Guardrails**                                                                 │
# │      *   Increased focus on developing sophisticated alignment techniques, bias detection and mitigation        │
# │  strategies, and robust safety protocols.                                                                       │
# │      *   The goal is to ensure LLMs are fair, transparent, and operate within ethical boundaries, especially    │
# │  in sensitive applications.                                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## 2. Agentic AI & Multi-Agent Systems: Towards Autonomy                                                       │
# │                                                                                                                 │
# │  Agentic AI refers to systems capable of autonomous action, planning, and tool use. Multi-agent systems         │
# │  involve multiple such agents collaborating.                                                                    │
# │                                                                                                                 │
# │  *   **Autonomous Agent Workflows in Production**                                                               │
# │      *   Agentic AI will transition from experimental setups to full production environments.                   │
# │      *   Autonomous agents will execute complex, multi-step tasks, utilize diverse tools, and self-correct      │
# │  errors with minimal human oversight across various business functions.                                         │
# │                                                                                                                 │
# │  *   **Sophisticated Human-Agent Collaboration**                                                                │
# │      *   The focus will shift from simple human-in-the-loop validation to deep collaborative frameworks.        │
# │      *   Humans and AI agents will work synergistically, with agents proactively seeking human input for        │
# │  ambiguity, complex decisions, or ethical considerations.                                                       │
# │                                                                                                                 │
# │  *   **Emergence of Agent Orchestration Platforms**                                                             │
# │      *   Dedicated platforms will mature to manage, monitor, and coordinate multiple specialized agents.        │
# │      *   These platforms will define roles, communication protocols, task dependencies, and resource            │
# │  allocation within complex multi-agent systems.                                                                 │
# │                                                                                                                 │
# │  *   **Domain-Specific Intelligent Agents**                                                                     │
# │      *   Expect a proliferation of highly specialized agents, deeply embedded with domain knowledge and access  │
# │  to proprietary tools and data.                                                                                 │
# │      *   These agents will be tailored for specific industries such as legal, finance, healthcare, and          │
# │  engineering.                                                                                                   │
# │                                                                                                                 │
# │  *   **Adaptive and Self-Improving Agents**                                                                     │
# │      *   Agents will increasingly incorporate continuous learning mechanisms.                                   │
# │      *   This allows them to adapt to new information, learn from feedback, and improve their performance and   │
# │  decision-making capabilities over time without explicit retraining.                                            │
# │                                                                                                                 │
# │  *   **Standardization of Agent Protocols**                                                                     │
# │      *   Efforts will intensify to establish common communication protocols, API standards, and                 │
# │  interoperability frameworks for agents.                                                                        │
# │      *   This will foster a more cohesive and scalable multi-agent ecosystem.                                   │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## 3. Enterprise Adoption: Integrating AI into Business                                                        │
# │                                                                                                                 │
# │  Enterprises are moving beyond pilots to integrate Generative AI and Agentic AI into core business processes,   │
# │  focusing on measurable value.                                                                                  │
# │                                                                                                                 │
# │  *   **GenAI as a Core Business Process Automation Enabler**                                                    │
# │      *   Enterprises will integrate GenAI and agentic systems directly into core operational processes.         │
# │      *   This will automate tasks in areas like supply chain management, R&D, legal discovery, software         │
# │  development, and customer experience, driving significant efficiency gains.                                    │
# │                                                                                                                 │
# │  *   **Hybrid and On-Premise Deployments for Data Sovereignty**                                                 │
# │      *   Increased demand for deploying GenAI models and agentic systems within private cloud environments or   │
# │  on-premise.                                                                                                    │
# │      *   This addresses stringent data privacy, security, compliance, and intellectual property requirements.   │
# │                                                                                                                 │
# │  *   **Data-Centric AI for Competitive Advantage**                                                              │
# │      *   Enterprises will heavily invest in curating, cleaning, and leveraging their proprietary data for       │
# │  fine-tuning LLMs and enhancing Retrieval Augmented Generation (RAG) systems.                                   │
# │      *   Unique data is recognized as key to differentiated GenAI capabilities and reducing hallucinations.     │
# │                                                                                                                 │
# │  *   **ROI-Driven Implementations and Value Realization**                                                       │
# │      *   The focus will shift from exploratory pilots to measurable business outcomes and clear return on       │
# │  investment (ROI) for GenAI initiatives.                                                                        │
# │      *   This requires robust metrics and strategic alignment with business goals.                              │
# │                                                                                                                 │
# │  *   **Workforce Transformation and Upskilling**                                                                │
# │      *   Significant investment in training and reskilling programs for employees to effectively interact       │
# │  with, manage, and leverage GenAI and agentic tools.                                                            │
# │      *   The goal is to foster a human-AI augmented workforce.                                                  │
# │                                                                                                                 │
# │  *   **Robust Governance, Risk, and Compliance (GRC) Frameworks**                                               │
# │      *   Development and implementation of comprehensive internal policies, ethical guidelines, and technical   │
# │  controls to manage GenAI risks.                                                                                │
# │      *   This includes addressing data leakage, bias, intellectual property, and regulatory compliance.         │
# │                                                                                                                 │
# │  *   **Vertical-Specific GenAI Solutions**                                                                      │
# │      *   A surge in industry-tailored GenAI applications and platforms.                                         │
# │      *   These solutions will offer pre-trained models and specialized tools designed to address unique         │
# │  challenges and opportunities within specific sectors.                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## 4. Tools and Frameworks: Enabling Development and Deployment                                                │
# │                                                                                                                 │
# │  The ecosystem of tools and frameworks supporting Generative AI and Agentic AI is maturing rapidly, offering    │
# │  more sophisticated and accessible options.                                                                     │
# │                                                                                                                 │
# │  *   **Advanced Agent Orchestration and Management Platforms**                                                  │
# │      *   Evolution of frameworks like LangChain and AutoGen into comprehensive enterprise-grade platforms.      │
# │      *   These will offer robust features for agent lifecycle management, monitoring, debugging, security, and  │
# │  scalable deployment of multi-agent systems.                                                                    │
# │                                                                                                                 │
# │  *   **Next-Generation RAG Systems**                                                                            │
# │      *   Tools for Retrieval Augmented Generation will become significantly more sophisticated.                 │
# │      *   They will incorporate multi-modal retrieval, knowledge graph integration, semantic search, and         │
# │  adaptive retrieval strategies to provide more accurate, contextually rich, and up-to-date responses.           │
# │                                                                                                                 │
# │  *   **Model Evaluation, Observability, and Governance (MLEO) for GenAI**                                       │
# │      *   Specialized tools will emerge to address the unique challenges of evaluating, monitoring, and          │
# │  governing GenAI models in production.                                                                          │
# │      *   Focus areas include hallucination detection, bias monitoring, prompt injection defense, and            │
# │  performance drift.                                                                                             │
# │                                                                                                                 │
# │  *   **Low-Code/No-Code GenAI Development Environments**                                                        │
# │      *   Platforms will empower business users and citizen developers to build, customize, and deploy GenAI     │
# │  applications and agentic workflows with minimal coding.                                                        │
# │      *   This democratizes access to advanced AI capabilities.                                                  │
# │                                                                                                                 │
# │  *   **Open-Source Dominance and Innovation**                                                                   │
# │      *   The open-source community will continue to drive rapid innovation in LLM architectures, agent          │
# │  frameworks, and specialized tooling.                                                                           │
# │      *   Often providing more flexible, customizable, and cost-effective alternatives to proprietary            │
# │  solutions.                                                                                                     │
# │                                                                                                                 │
# │  *   **Enhanced Data Preparation and Annotation Tools for GenAI**                                               │
# │      *   Specialized tools will streamline the process of curating, cleaning, augmenting, and annotating        │
# │  high-quality datasets.                                                                                         │
# │      *   These are specifically for LLM fine-tuning, RAG system development, and prompt engineering.            │
# │                                                                                                                 │
# │  *   **AI Security and Red Teaming Tools**                                                                      │
# │      *   A new generation of tools will focus on identifying and mitigating security vulnerabilities,           │
# │  adversarial attacks, and potential misuse of GenAI models.                                                     │
# │      *   This includes prompt injection, data exfiltration, and model poisoning.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 7da48bc5-bc1d-479d-b805-aef1cb43eb06                                                                     │
# │  Agent: Technical Writer                                                                                        │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: AI Reviewer                                                                                             │
# │                                                                                                                 │
# │  Task: Review the technical explanation for:                                                                    │
# │  - Accuracy                                                                                                     │
# │  - Clarity                                                                                                      │
# │  - Logical flow                                                                                                 │
# │  - Suitability for workshops                                                                                    │
# │                                                                                                                 │
# │  Provide the final polished version.                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ================================================================================
# FINAL OUTPUT
# ================================================================================
# Thought: The user wants me to review the provided content for accuracy, clarity, logical flow, and suitability for workshops. My final output must be the complete, polished content.
#
# I have gone through each section and bullet point of the provided text.
# -   **Accuracy**: All technical explanations are accurate and reflect current understanding and anticipated trends in the field.
# -   **Clarity**: The language is clear, concise, and avoids unnecessary jargon while still being technically precise. The use of bullet points and sub-points enhances readability.
# -   **Logical Flow**: The content is well-structured, starting with an introduction, then moving through LLMs, Agentic AI, Enterprise Adoption, and finally Tools & Frameworks. Within each section, the trends are presented logically.
# -   **Suitability for Workshops**: The tone is professional and informative, perfect for a workshop setting. The structure with clear headings and bullet points makes it easy to follow, present, and potentially discuss each trend. The introductory and concluding sentences for each major section provide good context.
#
# The content is already very high quality and meets all the specified criteria. No significant changes or edits are required to improve it. I will present the content as is, as it is already a polished, workshop-ready version.# Generative AI & Agentic AI Trends 2025: A Technical Workshop Overview
#
# Welcome to this workshop on the anticipated trends shaping Generative AI and Agentic AI in 2025. We'll explore how these technologies are evolving, their impact on enterprise adoption, and the tools and frameworks driving their development. Our goal is to provide a clear, structured understanding for professionals looking to leverage these advancements.
#
# ---
#
# ## 1. Large Language Models (LLMs): Evolution and Capabilities
#
# Large Language Models are rapidly advancing beyond their text-centric origins, becoming more versatile, intelligent, and efficient.
#
# *   **Multimodality as the Default**
#     *   LLMs will natively process and generate content across various data types: text, images, audio, video, and potentially other sensory inputs.
#     *   This shift enables a more holistic understanding of and interaction with the world, moving beyond simple text processing.
#
# *   **Specialized and Efficient Models (SLMs/sLLMs)**
#     *   Expect a strong trend towards smaller, highly specialized, and fine-tuned models (Small Language Models).
#     *   These models are optimized for specific domains, tasks, or edge deployments, offering superior performance, lower latency, and reduced inference costs compared to large, general-purpose models.
#
# *   **Enhanced Reasoning and Planning Capabilities**
#     *   Significant architectural and training advancements will lead to improved logical reasoning, complex problem-solving, multi-step planning, and self-correction.
#     *   This will reduce "hallucinations" and increase reliability, making LLMs suitable for critical applications.
#
# *   **Deep Personalization and Contextual Awareness**
#     *   LLMs will become highly adept at understanding individual user preferences, historical interactions, and real-time context.
#     *   This enables highly personalized experiences in areas like customer service, content generation, and intelligent assistance.
#
# *   **Cost-Efficiency and Optimization**
#     *   Continuous innovation in model compression (e.g., quantization, distillation), efficient inference techniques, and novel architectures will drastically reduce operational costs.
#     *   This makes deploying and scaling LLMs more accessible for broader enterprise adoption.
#
# *   **Robust Alignment and Safety Guardrails**
#     *   Increased focus on developing sophisticated alignment techniques, bias detection and mitigation strategies, and robust safety protocols.
#     *   The goal is to ensure LLMs are fair, transparent, and operate within ethical boundaries, especially in sensitive applications.
#
# ---
#
# ## 2. Agentic AI & Multi-Agent Systems: Towards Autonomy
#
# Agentic AI refers to systems capable of autonomous action, planning, and tool use. Multi-agent systems involve multiple such agents collaborating.
#
# *   **Autonomous Agent Workflows in Production**
#     *   Agentic AI will transition from experimental setups to full production environments.
#     *   Autonomous agents will execute complex, multi-step tasks, utilize diverse tools, and self-correct errors with minimal human oversight across various business functions.
#
# *   **Sophisticated Human-Agent Collaboration**
#     *   The focus will shift from simple human-in-the-loop validation to deep collaborative frameworks.
#     *   Humans and AI agents will work synergistically, with agents proactively seeking human input for ambiguity, complex decisions, or ethical considerations.
#
# *   **Emergence of Agent Orchestration Platforms**
#     *   Dedicated platforms will mature to manage, monitor, and coordinate multiple specialized agents.
#     *   These platforms will define roles, communication protocols, task dependencies, and resource allocation within complex multi-agent systems.
#
# *   **Domain-Specific Intelligent Agents**
#     *   Expect a proliferation of highly specialized agents, deeply embedded with domain knowledge and access to proprietary tools and data.
#     *   These agents will be tailored for specific industries such as legal, finance, healthcare, and engineering.
#
# *   **Adaptive and Self-Improving Agents**
#     *   Agents will increasingly incorporate continuous learning mechanisms.
#     *   This allows them to adapt to new information, learn from feedback, and improve their performance and decision-making capabilities over time without explicit retraining.
#
# *   **Standardization of Agent Protocols**
#     *   Efforts will intensify to establish common communication protocols, API standards, and interoperability frameworks for agents.
#     *   This will foster a more cohesive and scalable multi-agent ecosystem.
#
# ---
#
# ## 3. Enterprise Adoption: Integrating AI into Business
#
# Enterprises are moving beyond pilots to integrate Generative AI and Agentic AI into core business processes, focusing on measurable value.
#
# *   **GenAI as a Core Business Process Automation Enabler**
#     *   Enterprises will integrate GenAI and agentic systems directly into core operational processes.
#     *   This will automate tasks in areas like supply chain management, R&D, legal discovery, software development, and customer experience, driving significant efficiency gains.
#
# *   **Hybrid and On-Premise Deployments for Data Sovereignty**
#     *   Increased demand for deploying GenAI models and agentic systems within private cloud environments or on-premise.
#     *   This addresses stringent data privacy, security, compliance, and intellectual property requirements.
#
# *   **Data-Centric AI for Competitive Advantage**
#     *   Enterprises will heavily invest in curating, cleaning, and leveraging their proprietary data for fine-tuning LLMs and enhancing Retrieval Augmented Generation (RAG) systems.
#     *   Unique data is recognized as key to differentiated GenAI capabilities and reducing hallucinations.
#
# *   **ROI-Driven Implementations and Value Realization**
#     *   The focus will shift from exploratory pilots to measurable business outcomes and clear return on investment (ROI) for GenAI initiatives.
#     *   This requires robust metrics and strategic alignment with business goals.
#
# *   **Workforce Transformation and Upskilling**
#     *   Significant investment in training and reskilling programs for employees to effectively interact with, manage, and leverage GenAI and agentic tools.
#     *   The goal is to foster a human-AI augmented workforce.
#
# *   **Robust Governance, Risk, and Compliance (GRC) Frameworks**
#     *   Development and implementation of comprehensive internal policies, ethical guidelines, and technical controls to manage GenAI risks.
# ...
# │                                                                                                                 │
# │  *   **Cost-Efficiency and Optimization**                                                                       │
# │      *   Continuous innovation in model compression (e.g., quantization, distillation), efficient inference     │
# │  techniques, and novel architectures will drastically reduce operational costs.                                 │
# │      *   This makes deploying and scaling LLMs more accessible for broader enterprise adoption.                 │
# │                                                                                                                 │
# │  *   **Robust Alignment and Safety Guardrails**                                                                 │
# │      *   Increased focus on developing sophisticated alignment techniques, bias detection and mitigation        │
# │  strategies, and robust safety protocols.                                                                       │
# │      *   The goal is to ensure LLMs are fair, transparent, and operate within ethical boundaries, especially    │
# │  in sensitive applications.                                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## 2. Agentic AI & Multi-Agent Systems: Towards Autonomy                                                       │
# │                                                                                                                 │
# │  Agentic AI refers to systems capable of autonomous action, planning, and tool use. Multi-agent systems         │
# │  involve multiple such agents collaborating.                                                                    │
# │                                                                                                                 │
# │  *   **Autonomous Agent Workflows in Production**                                                               │
# │      *   Agentic AI will transition from experimental setups to full production environments.                   │
# │      *   Autonomous agents will execute complex, multi-step tasks, utilize diverse tools, and self-correct      │
# │  errors with minimal human oversight across various business functions.                                         │
# │                                                                                                                 │
# │  *   **Sophisticated Human-Agent Collaboration**                                                                │
# │      *   The focus will shift from simple human-in-the-loop validation to deep collaborative frameworks.        │
# │      *   Humans and AI agents will work synergistically, with agents proactively seeking human input for        │
# │  ambiguity, complex decisions, or ethical considerations.                                                       │
# │                                                                                                                 │
# │  *   **Emergence of Agent Orchestration Platforms**                                                             │
# │      *   Dedicated platforms will mature to manage, monitor, and coordinate multiple specialized agents.        │
# │      *   These platforms will define roles, communication protocols, task dependencies, and resource            │
# │  allocation within complex multi-agent systems.                                                                 │
# │                                                                                                                 │
# │  *   **Domain-Specific Intelligent Agents**                                                                     │
# │      *   Expect a proliferation of highly specialized agents, deeply embedded with domain knowledge and access  │
# │  to proprietary tools and data.                                                                                 │
# │      *   These agents will be tailored for specific industries such as legal, finance, healthcare, and          │
# │  engineering.                                                                                                   │
# │                                                                                                                 │
# │  *   **Adaptive and Self-Improving Agents**                                                                     │
# │      *   Agents will increasingly incorporate continuous learning mechanisms.                                   │
# │      *   This allows them to adapt to new information, learn from feedback, and improve their performance and   │
# │  decision-making capabilities over time without explicit retraining.                                            │
# │                                                                                                                 │
# │  *   **Standardization of Agent Protocols**                                                                     │
# │      *   Efforts will intensify to establish common communication protocols, API standards, and                 │
# │  interoperability frameworks for agents.                                                                        │
# │      *   This will foster a more cohesive and scalable multi-agent ecosystem.                                   │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## 3. Enterprise Adoption: Integrating AI into Business                                                        │
# │                                                                                                                 │
# │  Enterprises are moving beyond pilots to integrate Generative AI and Agentic AI into core business processes,   │
# │  focusing on measurable value.                                                                                  │
# │                                                                                                                 │
# │  *   **GenAI as a Core Business Process Automation Enabler**                                                    │
# │      *   Enterprises will integrate GenAI and agentic systems directly into core operational processes.         │
# │      *   This will automate tasks in areas like supply chain management, R&D, legal discovery, software         │
# │  development, and customer experience, driving significant efficiency gains.                                    │
# │                                                                                                                 │
# │  *   **Hybrid and On-Premise Deployments for Data Sovereignty**                                                 │
# │      *   Increased demand for deploying GenAI models and agentic systems within private cloud environments or   │
# │  on-premise.                                                                                                    │
# │      *   This addresses stringent data privacy, security, compliance, and intellectual property requirements.   │
# │                                                                                                                 │
# │  *   **Data-Centric AI for Competitive Advantage**                                                              │
# │      *   Enterprises will heavily invest in curating, cleaning, and leveraging their proprietary data for       │
# │  fine-tuning LLMs and enhancing Retrieval Augmented Generation (RAG) systems.                                   │
# │      *   Unique data is recognized as key to differentiated GenAI capabilities and reducing hallucinations.     │
# │                                                                                                                 │
# │  *   **ROI-Driven Implementations and Value Realization**                                                       │
# │      *   The focus will shift from exploratory pilots to measurable business outcomes and clear return on       │
# │  investment (ROI) for GenAI initiatives.                                                                        │
# │      *   This requires robust metrics and strategic alignment with business goals.                              │
# │                                                                                                                 │
# │  *   **Workforce Transformation and Upskilling**                                                                │
# │      *   Significant investment in training and reskilling programs for employees to effectively interact       │
# │  with, manage, and leverage GenAI and agentic tools.                                                            │
# │      *   The goal is to foster a human-AI augmented workforce.                                                  │
# │                                                                                                                 │
# │  *   **Robust Governance, Risk, and Compliance (GRC) Frameworks**                                               │
# │      *   Development and implementation of comprehensive internal policies, ethical guidelines, and technical   │
# │  controls to manage GenAI risks.                                                                                │
# │      *   This includes addressing data leakage, bias, intellectual property, and regulatory compliance.         │
# │                                                                                                                 │
# │  *   **Vertical-Specific GenAI Solutions**                                                                      │
# │      *   A surge in industry-tailored GenAI applications and platforms.                                         │
# │      *   These solutions will offer pre-trained models and specialized tools designed to address unique         │
# │  challenges and opportunities within specific sectors.                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## 4. Tools and Frameworks: Enabling Development and Deployment                                                │
# │                                                                                                                 │
# │  The ecosystem of tools and frameworks supporting Generative AI and Agentic AI is maturing rapidly, offering    │
# │  more sophisticated and accessible options.                                                                     │
# │                                                                                                                 │
# │  *   **Advanced Agent Orchestration and Management Platforms**                                                  │
# │      *   Evolution of frameworks like LangChain and AutoGen into comprehensive enterprise-grade platforms.      │
# │      *   These will offer robust features for agent lifecycle management, monitoring, debugging, security, and  │
# │  scalable deployment of multi-agent systems.                                                                    │
# │                                                                                                                 │
# │  *   **Next-Generation RAG Systems**                                                                            │
# │      *   Tools for Retrieval Augmented Generation will become significantly more sophisticated.                 │
# │      *   They will incorporate multi-modal retrieval, knowledge graph integration, semantic search, and         │
# │  adaptive retrieval strategies to provide more accurate, contextually rich, and up-to-date responses.           │
# │                                                                                                                 │
# │  *   **Model Evaluation, Observability, and Governance (MLEO) for GenAI**                                       │
# │      *   Specialized tools will emerge to address the unique challenges of evaluating, monitoring, and          │
# │  governing GenAI models in production.                                                                          │
# │      *   Focus areas include hallucination detection, bias monitoring, prompt injection defense, and            │
# │  performance drift.                                                                                             │
# │                                                                                                                 │
# │  *   **Low-Code/No-Code GenAI Development Environments**                                                        │
# │      *   Platforms will empower business users and citizen developers to build, customize, and deploy GenAI     │
# │  applications and agentic workflows with minimal coding.                                                        │
# │      *   This democratizes access to advanced AI capabilities.                                                  │
# │                                                                                                                 │
# │  *   **Open-Source Dominance and Innovation**                                                                   │
# │      *   The open-source community will continue to drive rapid innovation in LLM architectures, agent          │
# │  frameworks, and specialized tooling.                                                                           │
# │      *   Often providing more flexible, customizable, and cost-effective alternatives to proprietary            │
# │  solutions.                                                                                                     │
# │                                                                                                                 │
# │  *   **Enhanced Data Preparation and Annotation Tools for GenAI**                                               │
# │      *   Specialized tools will streamline the process of curating, cleaning, augmenting, and annotating        │
# │  high-quality datasets.                                                                                         │
# │      *   These are specifically for LLM fine-tuning, RAG system development, and prompt engineering.            │
# │                                                                                                                 │
# │  *   **AI Security and Red Teaming Tools**                                                                      │
# │      *   A new generation of tools will focus on identifying and mitigating security vulnerabilities,           │
# │  adversarial attacks, and potential misuse of GenAI models.                                                     │
# │      *   This includes prompt injection, data exfiltration, and model poisoning.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
